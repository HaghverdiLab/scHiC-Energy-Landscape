# %% [markdown]
# ### Regenerating Figure 2D: Compartment Score Visualization
#
# To reproduce **Figure 2D**, run the scripts provided in the `/scripts/sc-compartment-score/` directory and follow the pipeline described there.
#
# The main script for generating the compartment score visualizations is:
#
# `
# higashi_compartment_score.py
# `
#
# Running this script will compute the compartment scores and generate the figures used for the analysis.The generated figures will be saved to the specified output directory.

# %%
import os
import glob
from IPython.display import display, Image, Markdown

image_files = sorted(glob.glob(os.path.join(out_dir, "new_aggregated_matrix_*.png")))

print(f"Found {len(image_files)} figures.\n")

for image_path in image_files:
    display(Markdown(f"## {os.path.basename(image_path)}"))
    display(Image(filename=image_path))
# Out:
# Found 3 figures.
# ## new_aggregated_matrix_ASC.png
# ## new_aggregated_matrix_OGC.png
# ## new_aggregated_matrix_OPC.png
