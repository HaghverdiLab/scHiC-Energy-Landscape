# %% [markdown]
# ### Regenerating Figure 3C: Ising Energy Analysis
#
# To reproduce **Figure 3C**, run the script:
#
# ```bash
# scripts/Ising-Energy/compute_energy.py
# ```
#
#
#
# Running this script computes the Ising energy for the input contact matrices and generates two figures.
#
# The generated figures are saved to the output directory specified in the script.

# %%
from IPython.display import Image, display

base = "/Users/mozhganoroujlu/Desktop/MOZHGUN/cell_fate/hi_c/codes_figures/folders/output_compartments/new/new/new_energy"

display(Image(filename=base + "_energy_by_celltype.png"))
display(Image(filename=base + "_energy_violin.png"))
