# %% [markdown]
# Run the script:
#
# `scHiC-Energy-Landscape/scripts/Ising-Energy/intraTAD_contacts.py`

# %%
import os
import glob
from IPython.display import display, Image, Markdown

image_files = sorted(glob.glob(os.path.join(OUTPUT_DIR, "Figure1_IntraTAD_Violin_Bootstrap.png")))

print(f"Found {len(image_files)} figures.\n")

for image_path in image_files:
    display(Markdown(f"## {os.path.basename(image_path)}"))
    display(Image(filename=image_path))
# Out:
# Found 1 figures.
# ## Figure1_IntraTAD_Violin_Bootstrap.png
