# %% [markdown]
# ### Regenerating Figure 3B: Ising Lattice Visualization
#
# To reproduce **Figure 3B**, run the scripts in the `/scripts/Ising-Energy/lattice.py` directory.
#
# These scripts generate the Ising lattice visualizations used in the paper and save the resulting figures to the specified output directory.
#
# The generated figures correspond to the visualizations presented in **Figure 3B**.

# %%
from IPython.display import Image, display



display(Image(filename = "/Users/mozhganoroujlu/Desktop/MOZHGUN/cell_fate/hi_c/codes_figures/folders/output_compartments/lattice_plots/new/avg_compartment_lattice_OPC.png"))
